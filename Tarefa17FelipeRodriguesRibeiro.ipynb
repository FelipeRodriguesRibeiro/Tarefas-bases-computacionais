# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tabela = pd.read_csv('https://raw.githubusercontent.com/FelipeRodriguesRibeiro/BasesComputacionais/master/aula9/dados/tabelaBrasileirao2018.csv')
tabela
# Out:
#            Data  Turno         Mandante  Placar do Mandante  \
# 0    14/04/2018      1         Cruzeiro                   0
# 1    14/04/2018      1          Vitória                   2
# 2    14/04/2018      1           Santos                   2
# 3    15/04/2018      1  América Mineiro                   3
# 4    15/04/2018      1    Internacional                   2
# ..          ...    ...              ...                 ...
# 375   2/12/2018      2       Fluminense                   1
# 376   2/12/2018      2            Ceará                   0
# 377   2/12/2018      2        Palmeiras                   3
# 378   2/12/2018      2           Grêmio                   1
# 379   2/12/2018      2            Sport                   2
#
#      Placar do Visitante        Visitante  \
# 0                      1           Grêmio
# 1                      2         Flamengo
# 2                      0            Ceará
# 3                      0            Sport
# ...

# %%
plt.figure()
plt.scatter(tabela['Público'],tabela['Renda (R$)'])
plt.title('Gráfico da Renda em função do público de cada jogo')
plt.show()

# %%
tabela['Renda (R$)'].corr(tabela['Público'])
# Out:
# 0.8365730756690009
