# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Questão 01

# %%
v = np.zeros(251)
v[0] = 10
for i in range(0,251,1):
 v[i] = v[i-1]+0.01*(-9.81)
 print(f'i={i},v={v[i]}')
# Out:
# i=0,v=-0.0981
# i=1,v=-0.1962
# i=2,v=-0.2943
# i=3,v=-0.3924
# i=4,v=-0.49050000000000005
# i=5,v=-0.5886
# i=6,v=-0.6867
# i=7,v=-0.7847999999999999
# i=8,v=-0.8828999999999999
# i=9,v=-0.9809999999999999
# i=10,v=-1.0791
# i=11,v=-1.1772
# i=12,v=-1.2753
# i=13,v=-1.3734000000000002
# i=14,v=-1.4715000000000003
# i=15,v=-1.5696000000000003
# i=16,v=-1.6677000000000004
# i=17,v=-1.7658000000000005
# i=18,v=-1.8639000000000006
# i=19,v=-1.9620000000000006
# i=20,v=-2.0601000000000007
# i=21,v=-2.158200000000001
# i=22,v=-2.256300000000001
# i=23,v=-2.354400000000001
# i=24,v=-2.452500000000001
# i=25,v=-2.550600000000001
# i=26,v=-2.648700000000001
# i=27,v=-2.7468000000000012
# i=28,v=-2.8449000000000013
# i=29,v=-2.9430000000000014
# i=30,v=-3.0411000000000015
# i=31,v=-3.1392000000000015
# i=32,v=-3.2373000000000016
# i=33,v=-3.3354000000000017
# i=34,v=-3.4335000000000018
# i=35,v=-3.531600000000002
# i=36,v=-3.629700000000002
# i=37,v=-3.727800000000002
# ...

# %%
y = np.zeros(251)
y[0] = 0
for i in range(0,251,1):
 y[i]= y[i-1]+0.01*v[i-1]
 print(f'i={i},y={y[i]}')
# Out:
# i=0,y=-0.2462309999999992
# i=1,y=-0.2472119999999992
# i=2,y=-0.2491739999999992
# i=3,y=-0.2521169999999992
# i=4,y=-0.2560409999999992
# i=5,y=-0.2609459999999992
# i=6,y=-0.2668319999999992
# i=7,y=-0.2736989999999992
# i=8,y=-0.2815469999999992
# i=9,y=-0.2903759999999992
# i=10,y=-0.3001859999999992
# i=11,y=-0.31097699999999917
# i=12,y=-0.3227489999999992
# i=13,y=-0.3355019999999992
# i=14,y=-0.3492359999999992
# i=15,y=-0.3639509999999992
# i=16,y=-0.3796469999999992
# i=17,y=-0.3963239999999992
# i=18,y=-0.4139819999999992
# i=19,y=-0.4326209999999992
# i=20,y=-0.4522409999999992
# i=21,y=-0.4728419999999992
# i=22,y=-0.4944239999999992
# i=23,y=-0.5169869999999992
# i=24,y=-0.5405309999999992
# i=25,y=-0.5650559999999992
# i=26,y=-0.5905619999999993
# i=27,y=-0.6170489999999993
# i=28,y=-0.6445169999999993
# i=29,y=-0.6729659999999994
# i=30,y=-0.7023959999999995
# i=31,y=-0.7328069999999994
# i=32,y=-0.7641989999999994
# i=33,y=-0.7965719999999994
# ...

# %%
t = np.zeros(251)
t[0] = 0
for i in range(1,251):
  t[i] = t[i-1] + 0.01
  print(f'i={i},t[i]={t[i]}')
# Out:
# i=1,t[i]=0.01
# i=2,t[i]=0.02
# i=3,t[i]=0.03
# i=4,t[i]=0.04
# i=5,t[i]=0.05
# i=6,t[i]=0.060000000000000005
# i=7,t[i]=0.07
# i=8,t[i]=0.08
# i=9,t[i]=0.09
# i=10,t[i]=0.09999999999999999
# i=11,t[i]=0.10999999999999999
# i=12,t[i]=0.11999999999999998
# i=13,t[i]=0.12999999999999998
# i=14,t[i]=0.13999999999999999
# i=15,t[i]=0.15
# i=16,t[i]=0.16
# i=17,t[i]=0.17
# i=18,t[i]=0.18000000000000002
# i=19,t[i]=0.19000000000000003
# i=20,t[i]=0.20000000000000004
# i=21,t[i]=0.21000000000000005
# i=22,t[i]=0.22000000000000006
# i=23,t[i]=0.23000000000000007
# i=24,t[i]=0.24000000000000007
# i=25,t[i]=0.25000000000000006
# i=26,t[i]=0.26000000000000006
# i=27,t[i]=0.2700000000000001
# i=28,t[i]=0.2800000000000001
# i=29,t[i]=0.2900000000000001
# i=30,t[i]=0.3000000000000001
# i=31,t[i]=0.3100000000000001
# i=32,t[i]=0.3200000000000001
# i=33,t[i]=0.3300000000000001
# i=34,t[i]=0.34000000000000014
# i=35,t[i]=0.35000000000000014
# i=36,t[i]=0.36000000000000015
# ...

# %%
plt.figure()
plt.plot(y,t)
plt.xlabel('y')
plt.ylabel('t')
plt.show()

# %%
plt.figure()
plt.plot(v,t)
plt.xlabel('v')
plt.ylabel('t')
plt.show()

# %% [markdown]
# Questão 02

# %%
N=100
x = 0.5
ln = 0
for i in range(1,N+1,1):
 ln = ln - (-1)**(i+1)-((x**i)/i)
ln
# Out:
# -0.6931471805599463

# %%
np.log(0.5)
# Out:
# -0.6931471805599453

# %% [markdown]
# Questão 03

# %%
N = 10
y = 0
t = np.arange(0,10,0.000001)
for i in range(1,N+1,1):
  y = y + (np.sin(2*i-1)*t)/2*i-1
x = 4/np.pi * y
print(f't={t},x={x}')
# Out:
# t=[0.000000e+00 1.000000e-06 2.000000e-06 ... 9.999997e+00 9.999998e+00
#  9.999999e+00],x=[-12.73239545 -12.73239677 -12.73239809 ... -25.9409632  -25.94096452
#  -25.94096584]

# %%
plt.figure()
plt.plot(x,t,marker = 'o')
plt.xlabel('x')
plt.ylabel('t')
plt.show()

# %%
N = 100
y = 0
t = np.arange(0,10,0.000001)
for i in range(1,N+1,1):
  y = y + (np.sin(2*i-1)*t)/2*i-1
x = 4/np.pi * y
print(f't={t},x={x}')
# Out:
# t=[0.000000e+00 1.000000e-06 2.000000e-06 ... 9.999997e+00 9.999998e+00
#  9.999999e+00],x=[-127.32395447 -127.32397291 -127.32399135 ... -311.7068807  -311.70689914
#  -311.70691758]

# %%
plt.figure()
plt.plot(x,t,marker = 'o')
plt.xlabel('x')
plt.ylabel('t')
plt.show()

# %%
N = 1000
y = 0
t = np.arange(0,10,0.000001)
for i in range(1,N+1,1):
  y = y + (np.sin(2*i-1)*t)/2*i-1
x = 4/np.pi * y
print(f't={t},x={x}')
# Out:
# t=[0.000000e+00 1.000000e-06 2.000000e-06 ... 9.999997e+00 9.999998e+00
#  9.999999e+00],x=[-1273.23954474 -1273.23940536 -1273.23926599 ...   120.49422539
#    120.49436476   120.49450413]

# %%
plt.figure()
plt.plot(x,t,marker = 'o')
plt.xlabel('x')
plt.ylabel('t')
plt.show()

# %%
N = 10000
y = 0
t = np.arange(0,10,0.000001)
for i in range(1,N+1,1):
  y = y + (np.sin(2*i-1)*t)/2*i-1
x = 4/np.pi * y
print(f't={t},x={x}')
# Out:
# t=[0.000000e+00 1.000000e-06 2.000000e-06 ... 9.999997e+00 9.999998e+00
#  9.999999e+00],x=[-12732.39544735 -12732.3985234  -12732.40159945 ... -43492.87412493
#  -43492.87720098 -43492.88027703]

# %%
plt.figure()
plt.plot(x,t,marker = 'o')
plt.xlabel('x')
plt.ylabel('t')
plt.show()
